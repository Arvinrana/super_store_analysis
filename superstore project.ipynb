# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Administrator\Desktop\SuperStore.csv")

# %%
df
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# ...

# %%
df.shape
# Out:
# (5901, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
# ...

# %%
df.describe(include  = 'object')
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# count             5901        5901        5901            5901        5901
# unique            3003         643         690               4         773
# top     CA-2020-100111  05-09-2019  26-09-2020  Standard Class    EP-13915
# freq                14          38          34            3451          27
#
#        Customer Name   Segment        Country           City       State  \
# count           5901      5901           5901           5901        5901
# unique           773         3              1            452          49
# top       Emily Phan  Consumer  United States  New York City  California
# freq              27      2997           5901            563        1189
#
#        Region       Product ID         Category Sub-Category  \
# count    5901             5901             5901         5901
# unique      4             1755                3           17
# ...

# %%
df.describe()
# Out:
#        Row ID+O6G3A1:R6        Sales     Quantity       Profit  Returns  ind1  \
# count       5901.000000  5901.000000  5901.000000  5901.000000    287.0   0.0
# mean        5022.422471   265.345589     3.781901    29.700408      1.0   NaN
# std         2877.977184   474.260645     2.212917   259.589138      0.0   NaN
# min            1.000000     0.836000     1.000000 -6599.978000      1.0   NaN
# 25%         2486.000000    71.976000     2.000000     1.795500      1.0   NaN
# 50%         5091.000000   128.648000     3.000000     8.502500      1.0   NaN
# 75%         7456.000000   265.170000     5.000000    28.615000      1.0   NaN
# max         9994.000000  9099.930000    14.000000  8399.976000      1.0   NaN
#
#        ind2
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
df.head(3)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 2              4920  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#      Category Sub-Category                                       Product Name  \
# 0   Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 1   Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 2  Technology       Phones                                        GE 30522EE2
#
# ...

# %%
df['Product Name'].unique()
# Out:
# array(['Bush Westfield Collection Bookcases, Medium Cherry Finish',
#        'GE 30522EE2',
#        'Recycled Steel Personal File for Hanging File Folders', ...,
#        'Iceberg Nesting Folding Chair, 19w x 6d x 43h',
#        'Memorex Micro Travel Drive 4 GB', 'Acco Glide Clips'],
#       dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Gaithersburg', 'Los Angeles', 'San Antonio', 'Broken Arrow',
#        'Charlotte', 'Philadelphia', 'Jacksonville', 'Oakland', 'Amarillo',
#        'Franklin', 'Raleigh', 'Fresno', 'Toledo', 'Seattle', 'Longview',
#        'Springfield', 'Columbus', 'Concord', 'Westfield', 'Fairfield',
#        'New York City', 'San Diego', 'Morristown', 'Fayetteville',
#        'Cleveland', 'Burlington', 'Gulfport', 'Plainfield',
#        'San Francisco', 'Chicago', 'Rockford', 'Dallas', 'Atlantic City',
#        'Atlanta', 'Arlington', 'Houston', 'Richmond', 'Sierra Vista',
#        'Rockville', 'Smyrna', 'Chattanooga', 'Lancaster', 'Tulsa',
#        'Clinton', 'Jackson', 'Belleville', 'Henderson', 'Long Beach',
#        'Nashville', 'Oceanside', 'Tampa', 'Milwaukee', 'Newark',
#        'La Crosse', 'Yonkers', 'Denver', 'Odessa', 'Bloomington',
#        'Round Rock', 'Miami', 'Mishawaka', 'Dover', 'Fort Worth',
#        'Glendale', 'Milford', 'Andover', 'Eagan', 'Vineland', 'Monroe',
# ...

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
df.drop(['ind1','ind2'], axis = 1 , inplace =  True )

# %%
df.head(2)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#   Region       Product ID   Category Sub-Category  \
# 0   East  FUR-BO-10004709  Furniture    Bookcases
# 1   East  FUR-BO-10004709  Furniture    Bookcases
#
#                                         Product Name   Sales  Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94         1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94         3
#
#     Profit  Returns  Payment Mode
# 0  28.2668      NaN        Online
# 1  38.2668      NaN        Online
#
# [2 rows x 21 columns]

# %%
df['Returns'].isnull().sum()
# Out:
# 5614

# %%
df.drop(['Returns'] , axis = 1 , inplace = True)

# %%
df.head(2)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg
#
#       State Region       Product ID   Category Sub-Category  \
# 0  Maryland   East  FUR-BO-10004709  Furniture    Bookcases
# 1  Maryland   East  FUR-BO-10004709  Furniture    Bookcases
#
#                                         Product Name   Sales  Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94         1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94         3
#
#     Profit Payment Mode
# 0  28.2668       Online
# 1  38.2668       Online

# %%
df.duplicated().sum()
# Out:
# 0

# %%
cat_column = ['Segment', 'Country', 'City', 'Category', 'Sub-Category', 'Payment Mode']
inconsistent_data = {col: df[col].unique() for col in cat_column}

# %%
inconsistent_data
# Out:
# {'Segment': array(['Corporate', 'Consumer', 'Home Office'], dtype=object),
#  'Country': array(['United States'], dtype=object),
#  'City': array(['Gaithersburg', 'Los Angeles', 'San Antonio', 'Broken Arrow',
#         'Charlotte', 'Philadelphia', 'Jacksonville', 'Oakland', 'Amarillo',
#         'Franklin', 'Raleigh', 'Fresno', 'Toledo', 'Seattle', 'Longview',
#         'Springfield', 'Columbus', 'Concord', 'Westfield', 'Fairfield',
#         'New York City', 'San Diego', 'Morristown', 'Fayetteville',
#         'Cleveland', 'Burlington', 'Gulfport', 'Plainfield',
#         'San Francisco', 'Chicago', 'Rockford', 'Dallas', 'Atlantic City',
#         'Atlanta', 'Arlington', 'Houston', 'Richmond', 'Sierra Vista',
#         'Rockville', 'Smyrna', 'Chattanooga', 'Lancaster', 'Tulsa',
#         'Clinton', 'Jackson', 'Belleville', 'Henderson', 'Long Beach',
#         'Nashville', 'Oceanside', 'Tampa', 'Milwaukee', 'Newark',
# ...

# %%
numerical_columns = ['Sales', 'Quantity', 'Profit']
outliers = {col: df[col].describe(percentiles=[.01, .05, .95, .99]) for col in numerical_columns}

# %%
outliers
# Out:
# {'Sales': count    5901.000000
#  mean      265.345589
#  std       474.260645
#  min         0.836000
#  1%          3.282000
#  5%          9.248000
#  50%       128.648000
#  95%       956.664800
#  99%      2396.400000
#  max      9099.930000
#  Name: Sales, dtype: float64,
#  'Quantity': count    5901.000000
#  mean        3.781901
#  std         2.212917
#  min         1.000000
#  1%          1.000000
#  5%          1.000000
#  50%         3.000000
#  95%         8.000000
#  99%        10.000000
#  max        14.000000
#  Name: Quantity, dtype: float64,
#  'Profit': count    5901.000000
#  mean       29.700408
#  std       259.589138
#  min     -6599.978000
#  1%       -299.811600
#  5%        -51.827200
#  50%         8.502500
#  95%       168.438400
#  99%       592.789600
#  max      8399.976000
#  Name: Profit, dtype: float64}

# %%
df.plot(kind = 'box')
# Out:
# <AxesSubplot:>
